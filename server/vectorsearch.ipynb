# %%
import json
import sys
import torch
from transformers import BertTokenizer
from bert_score import score as bert_score

# Initialize BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Function to calculate BERT score between user answer and correct answer
def calculate_bert_score(user_answer, correct_answer):
    P, R, F1 = bert_score([user_answer], [correct_answer], lang='en', model_type='bert-base-uncased')
    return F1.item()

# Function to check answer
def check_answer(question, user_answer, correct_answers):
    max_total_score = 0
    for correct_answer in correct_answers:
        correct_answer_lines = break_at_full_stop(correct_answer)
        max_score = -1
        for correct_answer_line in correct_answer_lines:
            bertscore_val = calculate_bert_score(user_answer, correct_answer_line)
            total_score = 1 * bertscore_val 
            max_score = max(max_score, total_score)
        max_total_score = max(max_score, max_total_score)
    return max_total_score

# Break text into lines at full stops
def break_at_full_stop(text):
    lines = text.split('.')
    # Remove any empty strings resulting from consecutive full stops
    lines = [line.strip() for line in lines if line.strip()]
    return lines

# Load input data
def load_input():
    input_data = json.loads(input())
    return input_data

# Main function to handle input and calculate score
def main():
    input_data = load_input()
    print("Received data:", input_data)  # Print received data
    question = input_data['question']
    user_answer = input_data['user_answer']
    correct_answers = input_data['correct_answers']
    
    user_answer_lines = break_at_full_stop(user_answer)
    maxscore = 0
    for user_answer_line in user_answer_lines:
        score = check_answer(question, user_answer_line, correct_answers)
        maxscore += score
    
    maxscore = maxscore / len(user_answer_lines)
    score_percentage = (-45 + 100 * maxscore) / 0.55
    
    output_data = {
        'score': score_percentage
    }
    
    # Output the result
    print(json.dumps(output_data))

if __name__ == "__main__":
    main()
# Out:
# Question: what is polymorphism?
# User's answer: In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass. This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability. By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development.
# 0.7096750736236572   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   Polymorphism is a concept in object-oriented programming where objects of different classes can be treated as objects of a common superclass
# 0.5448376536369324   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   This allows for flexibility and extensibility in code, enabling functions or methods to work with objects of various types, enhancing code reusability and modularity
# max total score is : 0.7096750736236572
# 0.6489250063896179   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   In object-oriented programming, polymorphism refers to the ability of different objects to respond to the same message or method call in different ways
# 0.5489513874053955   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   This enables flexibility and abstraction, allowing for the implementation of generic algorithms that can operate on objects of different types, enhancing code flexibility and maintainability
# max total score is : 0.7096750736236572
# 0.6945818066596985   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   Polymorphism is a fundamental principle in object-oriented programming, allowing objects to be treated as instances of their parent class
# 0.531057596206665   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   This enables the same method or function to behave differently based on the specific object being operated on, enhancing code flexibility, extensibility, and readability
# max total score is : 0.7096750736236572
# 0.7755476236343384   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   In the context of object-oriented programming, polymorphism enables objects of different types to be treated as instances of a common superclass
# 0.5356349349021912   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   This allows for the implementation of generic algorithms that can operate on objects of various types, promoting code reuse, scalability, and maintainability
# max total score is : 0.7755476236343384
# 0.7360817790031433   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   Polymorphism, a key concept in object-oriented programming, allows objects of different classes to be treated as instances of a shared superclass
# 0.5519517660140991   In the realm of object-oriented programming, polymorphism serves as a powerful mechanism allowing different classes to be perceived and utilized through a unified interface provided by a superclass   This facilitates code abstraction and flexibility, enabling functions or methods to operate on objects of diverse types without the need for explicit type checking, thereby promoting modular and reusable code design
# max total score is : 0.7755476236343384
# score is 0.7755476236343384
# max score is  0.7755476236343384
# 0.3991314470767975   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   Polymorphism is a concept in object-oriented programming where objects of different classes can be treated as objects of a common superclass
# 0.6425995826721191   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   This allows for flexibility and extensibility in code, enabling functions or methods to work with objects of various types, enhancing code reusability and modularity
# max total score is : 0.6425995826721191
# 0.39169856905937195   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   In object-oriented programming, polymorphism refers to the ability of different objects to respond to the same message or method call in different ways
# 0.6350358128547668   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   This enables flexibility and abstraction, allowing for the implementation of generic algorithms that can operate on objects of different types, enhancing code flexibility and maintainability
# max total score is : 0.6425995826721191
# 0.44632649421691895   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   Polymorphism is a fundamental principle in object-oriented programming, allowing objects to be treated as instances of their parent class
# 0.5886962413787842   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   This enables the same method or function to behave differently based on the specific object being operated on, enhancing code flexibility, extensibility, and readability
# max total score is : 0.6425995826721191
# 0.43117576837539673   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   In the context of object-oriented programming, polymorphism enables objects of different types to be treated as instances of a common superclass
# 0.6158819794654846   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   This allows for the implementation of generic algorithms that can operate on objects of various types, promoting code reuse, scalability, and maintainability
# max total score is : 0.6425995826721191
# 0.4367493689060211   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   Polymorphism, a key concept in object-oriented programming, allows objects of different classes to be treated as instances of a shared superclass
# 0.612795889377594   This not only enhances the adaptability and flexibility of the code but also fosters a modular approach, facilitating easier maintenance and scalability   This facilitates code abstraction and flexibility, enabling functions or methods to operate on objects of diverse types without the need for explicit type checking, thereby promoting modular and reusable code design
# max total score is : 0.6425995826721191
# score is 0.6425995826721191
# max score is  1.4181472063064575
# 0.48134270310401917   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   Polymorphism is a concept in object-oriented programming where objects of different classes can be treated as objects of a common superclass
# 0.5963410139083862   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   This allows for flexibility and extensibility in code, enabling functions or methods to work with objects of various types, enhancing code reusability and modularity
# max total score is : 0.5963410139083862
# 0.48834025859832764   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   In object-oriented programming, polymorphism refers to the ability of different objects to respond to the same message or method call in different ways
# 0.6059611439704895   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   This enables flexibility and abstraction, allowing for the implementation of generic algorithms that can operate on objects of different types, enhancing code flexibility and maintainability
# max total score is : 0.6059611439704895
# 0.5105773210525513   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   Polymorphism is a fundamental principle in object-oriented programming, allowing objects to be treated as instances of their parent class
# 0.5427418351173401   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   This enables the same method or function to behave differently based on the specific object being operated on, enhancing code flexibility, extensibility, and readability
# max total score is : 0.6059611439704895
# 0.517157256603241   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   In the context of object-oriented programming, polymorphism enables objects of different types to be treated as instances of a common superclass
# 0.5942063927650452   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   This allows for the implementation of generic algorithms that can operate on objects of various types, promoting code reuse, scalability, and maintainability
# max total score is : 0.6059611439704895
# 0.5081742405891418   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   Polymorphism, a key concept in object-oriented programming, allows objects of different classes to be treated as instances of a shared superclass
# 0.6713249683380127   By embracing polymorphism, developers can design systems that seamlessly accommodate new functionalities and variations without the need for extensive modifications, thus promoting robustness and efficiency in software development   This facilitates code abstraction and flexibility, enabling functions or methods to operate on objects of diverse types without the need for explicit type checking, thereby promoting modular and reusable code design
# max total score is : 0.6713249683380127
# score is 0.6713249683380127
# max score is  2.08947217464447
# 3
# 0.6964907248814901
# Score: 45/100
